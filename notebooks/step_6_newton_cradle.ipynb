# %%
from perfect_physics import World, Circle, Wall

circle_list = [Circle(x=1, y=0, r=1, vx=1, vy=0, m=1)]
for i in range(1, 6):
    circle_list.append(Circle(x=i * 2 + 4, y=0, r=1, vx=0, vy=0, m=1))
wall_list = [Wall(x0=0, y0=0, x1=0, y1=1), Wall(x0=20, y0=0, x1=20, y1=1)]
world = World(circle_list, wall_list, xlim=(-1, 21), ylim=(-2, 2))
world.show()
ss_calist, _ = world._tick([], hint_ssca_list=[])
world.show()
world._tock(ss_calist, [])
world.show()
pass
# Out:
# c:\Users\Carl\miniconda3\envs\physics\lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
from sympy import Rational
from perfect_physics import World, Circle, Wall

folder = r"m:/deldir/perfect_physics/part6/newton_cradle1"
circle_list = [Circle(x=1, y=0, r=1, vx=1, vy=0, m=1)]
for i in range(1, 6):
    circle_list.append(Circle(x=i * 2 + 4, y=0, r=1, vx=0, vy=0, m=1))
wall_list = [Wall(x0=0, y0=0, x1=0, y1=1), Wall(x0=20, y0=0, x1=20, y1=1)]
world = World(circle_list, wall_list, xlim=(-1, 21), ylim=(-2, 2))
world.show()
world._tick_no_collision(Rational(1, 24) * 10)
world.show()
pass
# Out:
# c:\Users\Carl\miniconda3\envs\physics\lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
import logging

logger = logging.getLogger()
logger.setLevel(logging.WARNING)

import numpy as np
from perfect_physics import World, Circle, Wall

folder = r"m:/deldir/perfect_physics/part6/newton_cradle1"
circle_list = [Circle(x=1, y=0, r=1, vx=1, vy=0, m=1)]
for i in range(1, 6):
    circle_list.append(Circle(x=i * 2 + 4, y=0, r=1, vx=0, vy=0, m=1))
wall_list = [Wall(x0=0, y0=0, x1=0, y1=1), Wall(x0=20, y0=0, x1=20, y1=1)]
world = World(circle_list, wall_list, xlim=(-1, 21), ylim=(-2, 2))
if True:
    world.run_in_place(5, show=True)
else:
    world.run_to_file(folder, 500)
    World.render_events(folder, slice=np.s_[:17])
    World.render(folder, speed_up=10, slice=np.s_[:51])
# Out:
# D:\OneDrive\Projects\Science\PerfectPhysics\perfectphysics\_misc.py:64: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   patches.Circle(
#
# D:\OneDrive\Projects\Science\PerfectPhysics\perfectphysics\_misc.py:101: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   figure.show()
#
# D:\OneDrive\Projects\Science\PerfectPhysics\perfectphysics\_misc.py:64: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   patches.Circle(
#
# D:\OneDrive\Projects\Science\PerfectPhysics\perfectphysics\_misc.py:101: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   figure.show()

# %%
import logging
import numpy as np
from perfect_physics import World, Circle, Wall

logger = logging.getLogger()
logger.setLevel(logging.WARNING)

folder = r"m:/deldir/perfect_physics/part6/newton_cradle2"

circle_list = [
    Circle(x=1, y=0, r=1, vx=1, vy=0, m=1),
    Circle(x=3, y=0, r=1, vx=1, vy=0, m=1),
    Circle(x=10, y=0, r=1, vx=0, vy=0, m=1),
    Circle(x=19, y=0, r=1, vx=-1, vy=0, m=1),
    Circle(x=17, y=0, r=1, vx=-1, vy=0, m=1),
]
wall_list = [Wall(x0=0, y0=0, x1=0, y1=1), Wall(x0=20, y0=0, x1=20, y1=1)]
world = World(circle_list, wall_list, xlim=(-1, 21), ylim=(-2, 2))
if False:
    world.run_in_place(7, show=True)
else:
    world.run_to_file(folder, 150)
    World.render_events(folder, slice=np.s_[0:25])
    World.render(folder, speed_up=10)
# Out:
# Moviepy - Building video m:\deldir\perfect_physics\part6\newton_cradle2\render_events\newton_cradle2.events.avi.
# MoviePy - Writing audio in newton_cradle2.eventsTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video m:\deldir\perfect_physics\part6\newton_cradle2\render_events\newton_cradle2.events.avi
# Moviepy - Done !
# Moviepy - video ready m:\deldir\perfect_physics\part6\newton_cradle2\render_events\newton_cradle2.events.avi
# Moviepy - Building video m:\deldir\perfect_physics\part6\newton_cradle2\render\newton_cradle2.avi.
# MoviePy - Writing audio in newton_cradle2TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video m:\deldir\perfect_physics\part6\newton_cradle2\render\newton_cradle2.avi
# Moviepy - Done !
# Moviepy - video ready m:\deldir\perfect_physics\part6\newton_cradle2\render\newton_cradle2.avi

# %%
import logging
from sympy import Rational
from perfect_physics import World, Circle, Wall

logger = logging.getLogger()
logger.setLevel(logging.WARNING)

folder = r"m:/deldir/perfect_physics/part6/newton_cradle_skew"

circle_list = [Circle(x=1, y=0, r=1, vx=1, vy=0, m=1, id="cue")]
for i in range(1, 6):
    circle_list.append(Circle(x=i * 2 + 4, y=0, r=1, vx=0, vy=0, m=1, id=f"b{i}"))
circle_list[3].y = Rational(1, 2)
wall_list = [Wall(x0=0, y0=0, x1=0, y1=1), Wall(x0=20, y0=0, x1=20, y1=1)]
world = World(circle_list, wall_list, xlim=(-1, 21), ylim=(-10, 10))
if False:
    world.show()
    # world.run_in_place(10, show=True)
else:
    world.run_to_file(folder, 27)
    # World.render_events(folder, slice=np.s_[0:25])
    World.render(folder, speed_up=10)
# Out:
# Moviepy - Building video m:\deldir\perfect_physics\part6\newton_cradle_skew\render\newton_cradle_skew.avi.
# MoviePy - Writing audio in newton_cradle_skewTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video m:\deldir\perfect_physics\part6\newton_cradle_skew\render\newton_cradle_skew.avi
# t:  99%|█████████▉| 105/106 [00:05<00:00, 20.99it/s, now=None]
# c:\Users\Carl\miniconda3\envs\physics\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:123: UserWarning: Warning: in file m:\deldir\perfect_physics\part6\newton_cradle_skew\render\misc\silent_video.avi, 6220800 bytes wanted but 0 bytes read,at frame 105/106, at time 4.38/4.38 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
# Moviepy - Done !
# Moviepy - video ready m:\deldir\perfect_physics\part6\newton_cradle_skew\render\newton_cradle_skew.avi

# %%
world = World.load(r"M:\deldir\perfect_physics\part6\two_size10\run\worlds\01069.world_cp")
world.show()
print(world.circle_list)
t0 = world.clock
vx0 = world.circle_list[1].vx
print(float(vx0))
world.tick_tock([],[])
world.tick_tock([],[])
world.show()
print(float(world.circle_list[1].vx))
print(1.0/float(world.clock-t0))
vx0
# Out:
# D:\OneDrive\Projects\Science\PerfectPhysics\perfectphysics\_misc.py:64: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   patches.Circle(
#
# D:\OneDrive\Projects\Science\PerfectPhysics\perfectphysics\_misc.py:101: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   figure.show()
#
# ...

# %%
from perfect_physics import World

world = World.load(r"M:\deldir\perfect_physics\part6\newton_cradle_skew\run\worlds\00026.world_cp")
# world.show()
world.circle_list[2].x
# Out:
# ((-120*sqrt(15) + 15*sqrt(225 - 8*sqrt(15)) + 4*sqrt(3375 - 120*sqrt(15)) + 3375)*(-27060*sqrt(3375 - 120*sqrt(15)) - 101025*sqrt(225 - 8*sqrt(15)) + 116880*sqrt(15) + 2451863)*(-1657350234326441931300 - 88899734745600*sqrt(-36965358000*sqrt(15) - 81816521790 + 2075621400*sqrt(15)*sqrt(225 - 8*sqrt(15)) + 8154284850*sqrt(225 - 8*sqrt(15))) + 6440586657600*sqrt(-510844891712*sqrt(15) - 931524962850 + 26785369080*sqrt(15)*sqrt(225 - 8*sqrt(15)) + 105709301550*sqrt(225 - 8*sqrt(15))) + 1826572159744*sqrt(-7662673375680*sqrt(15) - 13972874442750 + 401780536200*sqrt(15)*sqrt(225 - 8*sqrt(15)) + 1585639523250*sqrt(225 - 8*sqrt(15))) + 644983064136000*sqrt(-2464357200*sqrt(15) - 5454434786 + 138374760*sqrt(15)*sqrt(225 - 8*sqrt(15)) + 543618990*sqrt(225 - 8*sqrt(15))) + 9180850322712072600*sqrt(225 - 8*sqrt(15)) + 3584830276239787497*sqrt(3375 - 120*sqrt(15)) + 338162194461488069025*sqrt(15))*(-16910981712430533377536687650060239846409295499752228054176803628296*sqrt(3375 - 120*sqrt(15)) - 
# ...
