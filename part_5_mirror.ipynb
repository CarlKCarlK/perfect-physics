# %%
from pathlib import Path
root = Path("c:/deldir/perfect_physics")

# %%
from sympy import Rational, sqrt
from perfect_physics import World, Circle, Wall

half = Rational(1,2)

# c0 = Circle(x=0, y=half, vx=1, vy=0, m=half, r=half)
c1 = Circle(x=0, y=1+half, vx=1, vy=0, m=half, r=half)
c2 = Circle(x=3, y=2, vx=0, vy=0, m=1, r=1)
w0 = Wall(x0=0, y0=1, x1=1, y1=1)
w = World([c1, c2], wall_list=[w0], xlim=(-2,6),ylim=(-1,5))
w.run_in_place(5,show=True)
print(c0.x)
pass
# Out:
# 6 - sqrt(2)
