# %%
from pathlib import Path
root = Path("c:/deldir/perfect_physics")

# %%
import logging

logger = logging.getLogger()
logger.setLevel(logging.WARNING)

import numpy as np
from perfect_physics import World, Circle, Wall

folder = root / "part1/newton_cradle1"
circle_list = [Circle(x=1, y=0, r=1, vx=1, vy=0, m=1)]
for i in range(1, 6):
    circle_list.append(Circle(x=i * 2 + 4, y=0, r=1, vx=0, vy=0, m=1))
wall_list = [Wall(x0=0, y0=0, x1=0, y1=1), Wall(x0=20, y0=0, x1=20, y1=1)]
world = World(circle_list, wall_list, xlim=(-1, 21), ylim=(-2, 2))
if False:
    world.run_in_place(5, show=True)
else:
    world.run_to_file(folder, 100)
    World.render_events(folder, slice=np.s_[:17])
    World.render(folder, speed_up=10, slice=np.s_[:100])
# Out:
# Moviepy - Building video c:\deldir\perfect_physics\part1\newton_cradle1\render_events\newton_cradle1.events.avi.
# MoviePy - Writing audio in newton_cradle1.eventsTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video c:\deldir\perfect_physics\part1\newton_cradle1\render_events\newton_cradle1.events.avi
# Moviepy - Done !
# Moviepy - video ready c:\deldir\perfect_physics\part1\newton_cradle1\render_events\newton_cradle1.events.avi
# Moviepy - Building video c:\deldir\perfect_physics\part1\newton_cradle1\render\newton_cradle1.avi.
# MoviePy - Writing audio in newton_cradle1TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video c:\deldir\perfect_physics\part1\newton_cradle1\render\newton_cradle1.avi
# t:  99%|█████████▉| 161/162 [00:09<00:00, 17.82it/s, now=None]
# c:\Users\carlk\.conda\envs\physics38\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:123: UserWarning: Warning: in file c:\deldir\perfect_physics\part1\newton_cradle1\render\misc\silent_video.avi, 6220800 bytes wanted but 0 bytes read,at frame 161/162, at time 6.71/6.71 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
# Moviepy - Done !
# Moviepy - video ready c:\deldir\perfect_physics\part1\newton_cradle1\render\newton_cradle1.avi

# %%
from perfect_physics import World, Circle, Wall

circle_list = [Circle(x=1, y=0, r=1, vx=1, vy=0, m=1)]
for i in range(1, 6):
    circle_list.append(Circle(x=i * 2 + 4, y=0, r=1, vx=0, vy=0, m=1))
wall_list = [Wall(x0=0, y0=0, x1=0, y1=1), Wall(x0=20, y0=0, x1=20, y1=1)]
world = World(circle_list, wall_list, xlim=(-1, 21), ylim=(-2, 2))
world.show()
ss_calist, _ = world._tick([], hint_ssca_list=[])
world.show()
world._tock(ss_calist, [])
world.show()
pass

# %%
from sympy import Rational
from perfect_physics import World, Circle, Wall

circle_list = [Circle(x=1, y=0, r=1, vx=1, vy=0, m=1)]
for i in range(1, 6):
    circle_list.append(Circle(x=i * 2 + 4, y=0, r=1, vx=0, vy=0, m=1))
wall_list = [Wall(x0=0, y0=0, x1=0, y1=1), Wall(x0=20, y0=0, x1=20, y1=1)]
world = World(circle_list, wall_list, xlim=(-1, 21), ylim=(-2, 2))
world.show()
world._tick_no_collision(Rational(1, 24) * 10)
world.show()
pass
# Out:
# c:\Users\carlk\OneDrive\Projects\Science\perfect-physics\perfect_physics\_misc.py:101: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   figure.show()
