# %%
# https://www.cs.utexas.edu/users/evouga/uploads/4/5/6/8/45689883/term-revised.pdf

# %%
from pathlib import Path
root = Path("c:/deldir/perfect_physics")

# %%
from perfect_physics import World, Circle, Wall

w0 = Wall(x0=-2, y0=0, x1=-2, y1=1)
w1 = Wall(x0=2, y0=0, x1=2, y1=1)
c0 = Circle(x=-1, y=0, vx=0, vy=0, r=1, m=1)
c1 = Circle(x=1, y=0, vx=0, vy=0, r=1, m=1)
cue = Circle(x=0, y=3, vx=0, vy=-1, r=1, m=1)
world = World(wall_list=[w0, w1], circle_list=[c0, c1, cue],xlim=(-3,3), ylim=(-2,5))
world.run_in_place(10,show=True)
pass
# Out:
# c:\Users\carlk\OneDrive\Projects\Science\perfect-physics\perfect_physics\_misc.py:101: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   figure.show()
#
# Multiple collisions: 2
# Multiple collisions: 2
# Multiple collisions: 2
# Multiple collisions: 2
# Multiple collisions: 2
# Multiple collisions: 2

# %%
3
