# %%
from pathlib import Path
root = Path("c:/deldir/perfect_physics")

# %%
import logging

logger = logging.getLogger()
logger.setLevel(logging.WARNING)

import numpy as np
from perfect_physics import World, Circle, Wall

for rng in [0,1,2]:

    folder = root / "part1/newton_cradle1"
    circle_list = [Circle(x=-1, y=0, r=1, vx=1, vy=0, m=1),
                    Circle(x=3, y=0, r=1, vx=0, vy=0, m=1),
                    #Circle(x=7, y=0, r=1, vx=-1, vy=0, m=1),
                    Circle(x=7, y=0, r=1, vx=-1, vy=0, m=2),]
    wall_list = [Wall(x0=-5, y0=0, x1=-5, y1=1), Wall(x0=13, y0=0, x1=13, y1=1)]
    world = World(circle_list, wall_list, xlim=(-6, 21), ylim=(-2, 2), rng=rng)
    if True:
        world.run_in_place(3, show=True)
    else:
        world.run_to_file(folder, 100)
        World.render_events(folder, slice=np.s_[:17])
        World.render(folder, speed_up=10, slice=np.s_[:100])
# Out:
# Multiple collisions: 2
# Multiple collisions: 2
# Multiple collisions: 2
