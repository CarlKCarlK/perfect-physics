# %%
from pathlib import Path
root = Path("c:/deldir/perfect_physics")

# %%
from perfect_physics import World, Circle, Wall
from sympy import pi, cos, sin


for rng in range(4):
    print(rng)
    c0 = Circle(x=-2, y=0, vx=1, vy=0, r=1, m=1)
    c1 = Circle(x=0, y=0, vx=0, vy=0, r=1, m=1)
    c2 = Circle(x=2, y=0, vx=-2, vy=0, r=1, m=1)
    world = World(circle_list=[c0,c1,c2],xlim=(-6,6), ylim=(-3,3),rng=rng)
    world.run_in_place(3,show=True,font_scale=1)
pass
# Out:
# 0
# Multiple collisions: 2
# 1
# Multiple collisions: 2
# 2
# Multiple collisions: 2
# 3
# Multiple collisions: 2
